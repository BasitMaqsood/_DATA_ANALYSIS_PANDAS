# %% [markdown]
# # Create Series

# %%
import pandas as pd

# %%
data = pd.read_csv('sample1.csv')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(pd.read_csv('sample1.csv'))
# Out:
# pandas.core.frame.DataFrame

# %%
df= pd.read_csv('sample1.csv', header=None)

# %%
series = pd.read_csv('sample1.csv', header=None, squeeze=True)

# %%
series
# Out:
# 0        Basit Maqsood
# 1    Husnain Maqsood\n
# 2         Yasir Zahoor
# 3    Shahzaib Zahoor\n
# 4        Faisal Hafeez
# Name: 0, dtype: object

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
series2 = pd.read_csv('sample3.csv')

# %%
series2
# Out:
#     Emp ID Name Prefix First Name Middle Initial   Last Name Gender  \
# 0   677509        Drs.       Lois              H      Walker      F
# 1   940761         Ms.     Brenda              S    Robinson      F
# 2   428945         Dr.        Joe              W    Robinson      M
# 3   408351        Drs.      Diane              I       Evans      F
# 4   193819         Mr.   Benjamin              R     Russell      M
# 5   499687         Mr.    Patrick              F      Bailey      M
# 6   539712         Ms.      Nancy              T       Baker      F
# 7   380086        Mrs.      Carol              V      Murphy      F
# 8   477616        Hon.    Frances              B       Young      F
# 9   162402        Hon.      Diana              T    Peterson      F
# 10  231469         Mr.      Ralph              L      Flores      M
# 11  153989       Prof.       Jack              C   Alexander      M
# 12  386158        Mrs.    Melissa              Q        King      F
# ...

# %%
series3 = pd.read_csv('sample3.csv', squeeze=True, usecols=['Zip'])

# %%
series3
# Out:
# 0     80224
# 1     71078
# 2     46057
# 3     16328
# 4     54940
# 5     50155
# 6     30334
# 7     45107
# 8     78536
# 9     72632
# 10    66534
# 11    89170
# 12    45767
# 13    58255
# 14    15555
# 15    28518
# 16    62074
# 17    50481
# 18    38476
# 19    63745
# 20    71162
# 21    22473
# 22    45760
# 23    37190
# 24    34771
# 25    57264
# 26    58642
# 27    98273
# 28    38464
# 29    85208
#       ...
# 70    61748
# 71    64133
# 72    81045
# 73    81418
# 74    41607
# 75    16401
# 76    41310
# 77    74646
# 78    32569
# 79    60189
# 80    56658
# 81    78943
# 82    12983
# 83    19132
# 84    70749
# 85    67214
# 86    73760
# 87    13424
# 88    45673
# 89    33166
# 90    53490
# 91    99791
# 92    65305
# 93    93526
# 94    97453
# 95    39532
# 96    60351
# 97    48278
# 98    99627
# 99    48801
# Name: Zip, Length: 100, dtype: int64

# %%
type(series3)
# Out:
# pandas.core.series.Series
